# %% [markdown]
# This is the group work by Sun Hee Park, Manling Yang

# %% [markdown]
# # Introduction

# %%
import csv 
import josn
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\13750\Desktop\yu\DAV5400 Analytics Programming\Assignment\final proposal\day.csv")
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
# read the data file from SODA API address
#print the result
df1 = pd.read_csv('https://www.kaggle.com/akkithetechie/new-york-city-bike-share-dataset')
df1
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-25-d299e9ee8114> in <module>
#       1 # read the data file from SODA API address
#       2 #print the result
# ----> 3 df1 = pd.read_csv('https://www.kaggle.com/akkithetechie/new-york-city-bike-share-dataset')
#       4 df1
#
# ...

# %%
from urllib.request import urlopen
url = urlopen('https://www.kaggle.com/samratp/bikeshare-analysis#NYC-CitiBike-2016.csv')
url.read()
# Out:
# b'<!DOCTYPE html>\r\n<html lang="en">\r\n<head>\r\n    <title>BikeShare Analysis | Kaggle</title>\r\n    <meta charset="utf-8" />\r\n    <meta name="robots" content="index, follow" />\r\n    <meta name="description" content="Download Open Datasets on 1000s of Projects + Share Projects on One Platform. Explore Popular Topics Like Government, Sports, Medicine, Fintech, Food, More. Flexible Data Ingestion." />\r\n    <meta name="turbolinks-cache-control" content="no-cache" />\r\n        <meta name="keywords" content="arts and entertainment,leisure,web services,sport cycling,cycling" />\r\n        <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0">\r\n    <meta name="theme-color" content="#008ABC" />\r\n    <script nonce="r5nviLEt0purG4AoVF731Q==" type="text/javascript">\r\n        window["initialPageLoadStartTime"] = new Date().getTime();\r\n    </script>\r\n    <link rel="dns-prefetch" href="https://www.google-analytics.com" /><l
# ...

# %% [markdown]
# # reference:
# 1. The good analysis sample for bike: https://www.kaggle.com/rajmehra03/bike-sharing-demand-rmsle-0-3194 and https://www.kaggle.com/sohamsave/bike-renting-analysis (we can copy some function from here)
# 2. dataset 1: https://www.kaggle.com/samratp/bikeshare-analysis#Chicago-Divvy-2016.csv
# 3. dataset 2:https://www.kaggle.com/akkithetechie/new-york-city-bike-share-dataset
